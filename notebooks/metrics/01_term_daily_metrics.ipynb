# %% [markdown]
# # Term Daily Metrics

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.pipeline import run_analysis
result = run_analysis('두쫀쿠', ['youtube'], {'type': 'relative', 'days': 14}, True, 5, 'sample', save=False)
result['term_daily_df'].head()
