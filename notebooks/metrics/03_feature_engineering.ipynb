# %% [markdown]
# # Feature Engineering

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.pipeline import run_analysis
result = run_analysis('우베', ['youtube'], {'type': 'relative', 'days': 30}, True, 10, 'sample', save=False)
result['feature_df'].tail()
