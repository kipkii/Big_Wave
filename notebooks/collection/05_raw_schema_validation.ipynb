# %% [markdown]
# # Raw Schema Validation

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.collectors.contract import RAW_COLUMNS
RAW_COLUMNS
