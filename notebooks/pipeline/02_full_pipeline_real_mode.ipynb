# %% [markdown]
# # Full Pipeline - Real Mode
#
# Set API keys first. Real mode must fail clearly if keys are missing.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.pipeline import run_analysis
# result = run_analysis('두쫀쿠', ['youtube'], {'type': 'relative', 'days': 30}, True, 5, 'real', save=True)
# result['analysis_run'], result['ts_result']
