# %% [markdown]
# # Full Pipeline - Sample Mode

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.pipeline import run_analysis
result = run_analysis('임의키워드', ['youtube', 'naver_news', 'naver_blog'], {'type': 'relative', 'days': 30}, True, 5, 'sample', save=True)
result['analysis_run'], result['ts_result'], result['keyword_set']
