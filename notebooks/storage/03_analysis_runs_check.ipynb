# %% [markdown]
# # Analysis Runs Check

# %%
import sqlite3, sys
from pathlib import Path
ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT / 'backend'))
from src.config import DB_PATH
with sqlite3.connect(DB_PATH) as con:
    rows = con.execute('SELECT run_id, keyword, data_mode, created_at FROM analysis_runs ORDER BY created_at DESC LIMIT 10').fetchall()
rows
