# %% [markdown]
# # TS v1 Scoring

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[2]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.pipeline import run_analysis
result = run_analysis('두쫀쿠', ['youtube', 'naver_news', 'naver_blog'], {'type': 'relative', 'days': 30}, True, 10, 'sample', save=False)
result['ts_result']
