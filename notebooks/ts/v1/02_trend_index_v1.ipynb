# %% [markdown]
# # Trend Index v1

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[2]
sys.path.insert(0, str(ROOT / 'backend'))

# %%
from src.pipeline import run_analysis
result = run_analysis('버터떡', ['youtube'], {'type': 'relative', 'days': 30}, True, 10, 'sample', save=False)
result['trend_index_series'][:10]
