# %% [markdown]
# # TS v2 Experiment Placeholder
#
# Use this notebook for future scoring experiments. Production TS_v1 remains in `backend/src/ts/v1`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parents[2]
sys.path.insert(0, str(ROOT / 'backend'))
from src.ts.v2.scoring import calculate_ts_v2
calculate_ts_v2
