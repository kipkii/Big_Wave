# %% [markdown]
# # BigWave v2 Quickstart
#
# This notebook verifies the package import path and runs a sample-mode analysis.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
BACKEND = ROOT / 'backend'
sys.path.insert(0, str(BACKEND))
print(BACKEND)

# %%
from src.pipeline import run_analysis

result = run_analysis(
    keyword='두쫀쿠',
    sources=['youtube', 'naver_news', 'naver_blog'],
    period={'type': 'relative', 'days': 30},
    include_related=True,
    limit_per_term=5,
    data_mode='sample',
    save=False,
)
result['ts_result'], result['analysis_run']
