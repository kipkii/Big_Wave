# %% [markdown]
# # E3 Trend Analyzer Test
#
# This notebook imports analyzer_v2 functions and runs the full E3 flow from an E2 run folder.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from analyzer_v2 import run_e3_analysis

# %%
run_dir = PROJECT_ROOT / 'data' / 'raw' / 'run_20260526_150843_두쫀쿠'
selected_sources = None
analysis_days = 30
include_related = True

dashboard_data = run_e3_analysis(
    run_dir=str(run_dir),
    selected_sources=selected_sources,
    analysis_days=analysis_days,
    include_related=include_related,
    save=True,
)
dashboard_data['summary']

# %%
import pandas as pd
run_id = run_dir.name
processed_dir = PROJECT_ROOT / 'data' / 'processed' / run_id
results_dir = PROJECT_ROOT / 'data' / 'results' / run_id

pd.read_csv(processed_dir / 'term_daily_metrics.csv').head()

# %%
pd.read_csv(processed_dir / 'keyword_set_daily_metrics.csv').head()

# %%
pd.read_csv(results_dir / 'trend_index.csv').head()

# %%
import json
json.loads((results_dir / 'ts_score.json').read_text(encoding='utf-8'))

# %%
json.loads((results_dir / 'dashboard_data.json').read_text(encoding='utf-8')).keys()
